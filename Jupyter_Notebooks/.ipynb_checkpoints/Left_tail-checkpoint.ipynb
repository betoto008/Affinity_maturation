# %%
import sys
sys.path.append('../Codes/')
import numpy as np
import matplotlib.pyplot as plt
from Immuno_models import*
#from Bio import Phylo
from io import StringIO
from matplotlib.lines import Line2D
from datetime import datetime, timedelta
import scipy.special as sc
import os.path
import pickle
from matplotlib import style
from scipy.interpolate import interp1d
from scipy.optimize import curve_fit
from IPython.display import display, Math

def my_linear_func(x, a, b):
    return a + b*x
def my_quadratic_func(x, a, b, c):
    return np.log(a)+np.log(np.sqrt(-b)) + b*(x-c)**2

N_A = 6.02214076e23
k_BT = 1.380649e-23*293
style.use('seaborn-paper')
print(style.available)
# %autosave 60
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']
# Autosaving every 60 seconds

# %%
# %%time
n_seq = 500000

#Sequences = generate_Sequences(n_seq, Energy_Matrix = )
#pickle.dump( Sequences, open( "../Text_files/Sequences-n_seq-%d.pkl"%(n_seq), "wb" ) )

Sequences = pickle.load( open( "../Text_files/Sequences_MJ2-n_seq-%d.pkl"%(n_seq), "rb" ) )
# Out:
# CPU times: user 3.93 s, sys: 285 ms, total: 4.22 s
# Wall time: 4.25 s

# %%
#___________________________________________
fig, ax = plt.subplots(1,1,figsize=(10,8))
distances = plot_histogram_hamming_distance(Sequences = Sequences, ax = ax)
plt.close()
#___________________________________________
fig, ax = plt.subplots(1,1,figsize=(10,8))
energies, data_energies = plot_histogram_energy(Sequences = Sequences, bins = 'auto', ax = ax)
ax.set_xlim(np.min(energies),np.min(energies)+5 )
# Out:
# (-40.03, -35.03)

# %%
# %%time
#Left_tail = np.array([Sequences[i] for i in range(int(len(Sequences))) if (Sequences[i].energy < np.min(energies)+4) ])
#pickle.dump( Left_tail, open( "../Text_files/Sequences_MJ2_left_tail-n_seq-%d.pkl"%(int(n_seq)), "wb" ) )
Left_tail = pickle.load(open( "../Text_files/Sequences_MJ2_left_tail-n_seq-%d.pkl"%(int(n_seq)), "rb" ) )
# Out:
# CPU times: user 17.7 ms, sys: 2.34 ms, total: 20 ms
# Wall time: 49.4 ms

# %%
# %%time
#____________ Create sub_energies (uncomment when kernel is restarted)
n_linages = 200
sub_energies = np.array([])
for i in range(1000):
    Sub_Sequences = np.random.choice(Sequences, n_linages)
    sub_energies = np.append(sub_energies,np.array([i.energy for i in Sub_Sequences]))
# Out:
# CPU times: user 524 ms, sys: 178 ms, total: 702 ms
# Wall time: 703 ms

# %%
#___________________________________________
fig, ax = plt.subplots(1,1,figsize=(10,8))
distances_left_tail = plot_histogram_hamming_distance(Sequences = Left_tail, ax = ax)
plt.close()
#___________________________________________
fig, ax = plt.subplots(1,1,figsize=(10,8))
energies_left_tail, data_energies_left_tail = plot_histogram_energy(Sequences = Left_tail, bins = 'auto' , ax = ax)
ax.set_xlim(np.min(energies),np.min(energies)+4 )

popt, pcov = curve_fit(my_linear_func, data_energies_left_tail[1][0:-1][np.where(data_energies_left_tail[0]!=0)], np.log(data_energies_left_tail[0][np.where(data_energies_left_tail[0]!=0)]))
e_new = np.linspace(np.min(energies),np.min(energies)+4,100)
ax.plot(e_new, np.exp(my_linear_func(e_new, *popt)), linestyle  = 'dashed', linewidth = 3, color = 'darkblue', alpha = .5)
ax.set_ylabel(r'$S(\epsilon)$')
print(*popt)
# Out:
# 51.864097479582654 1.259335478761019

# %%
#___________________________________________
fig, ax = plt.subplots(1,1, figsize = (10, 8))
plot_scatter_hamming_distance_energy(distances = distances, energies = energies, color = 'steelblue', ax = ax)
plot_scatter_hamming_distance_energy(distances = distances_left_tail, energies = energies_left_tail, color = 'olive', ax = ax)
fig.savefig('../Figures/Scatter_sequences_left_tail.png')

# %% [markdown]
# ## Single run

# %%
# %%time
n_linages = 200
U = n_linages/n_seq
nu = .5
beta = 3
gamma = 3
T = 15
energy_translation = 20
initial_time = 0
dt = 0.002
Sub_Sequences = np.random.choice(Left_tail, n_linages)
for i in range(n_linages):
    Sub_Sequences[i].active = False
Model  = Deterministic_simulation(Sequences = Sub_Sequences, n_linages=n_linages, T = T,
                                  U = U, nu = nu, beta = beta, gamma = gamma,
                                  energy_translation = energy_translation,
                                  initial_time = initial_time, dt = dt)
Model.ODE()

fig, ax = plt.subplots(1,1,figsize=(20,8))
Model.plot_antigen_time(ax = ax)
ax.set_ylim(np.exp(Model.beta*initial_time)/N_A, (np.max(Model.antigen_time_series)/N_A)*2)
ax.plot(Model.time_series, np.exp(Model.time_series*beta)/Model.N_A, linewidth = 3, linestyle = 'dashed', alpha = 0.4, color = 'steelblue')
# Out:
# CPU times: user 22.4 s, sys: 163 ms, total: 22.6 s
# Wall time: 22.7 s

# %%
to = (np.min(energies)+np.log(N_A))/beta
print('to = ', to)
# Out:
# to =  4.908299980981224

# %%
fig, ax = plt.subplots(1,1,figsize=(10,8))
m_array = np.linspace(.2,10,100)
ax.plot(m_array, m_array*beta*b, color = 'indigo')
ax.plot(m_array, (((beta*(beta*b-nu))/(gamma))/(1-(m_array*beta*b+1)**((nu/(beta*b))-1)))-1, color = 'steelblue')
ax.hlines((beta*(beta*b-nu))/(gamma)-1, .2, 5, linestyle = 'dashed')

# %%
fig, ax = plt.subplots(1,2,figsize=(20,8))
Model.plot_antigen_time(ax = ax[0])
Model.plot_prob_binding(ax = ax[1])
ax[1].set_yscale('linear')
counter = 0
while(os.path.isfile('../Figures/Antigen_Binding_%d.png'%(counter))):
    counter+=1
#fig.savefig('../Figures/Antigen_Binding_%d.png'%(0))
#--------------------------------------------------------------------------------------------------------------------
fig, ax = plt.subplots(1,1,figsize=(10,8))
Model.stackplot_linages_time(antigen = False, time = True, ax = ax)
counter = 0
while(os.path.isfile('../Figures/Linages_%d.png'%(counter))):
    counter+=1
#fig.savefig('../Figures/Linages_%d.png'%(0))
#--------------------------------------------------------------------------------------------------------------------
fig, ax = plt.subplots(1,2,figsize=(20,8))
Model.hist_sequences_hamming_distance(Sequences = Sequences, ax = ax[0])
Model.hist_sequences_energy(Sequences = Sequences, n_bins = 20, ax = ax[1])
counter = 0
while(os.path.isfile('../Figures/Histograms_hamming_energy_%d.png'%(counter))):
    counter+=1
#fig.savefig('../Figures/Histograms_hamming_energy_%d.png'%(0))
#--------------------------------------------------------------------------------------------------------------------
fig, ax = plt.subplots(1,1,figsize=(10,8))
Model.hist_sequences_k_D(Sequences = Sequences, n_bins = 20, ax = ax)
ax.set_xscale('log')
ax.set_xlabel(r'$k_D$', fontsize = 20)
counter = 0
while(os.path.isfile('../Figures/Histogram_k_D_%d.png'%(counter))):
    counter+=1
#fig.savefig('../Figures/Histogram_k_D_%d.png'%(0))

# %%
popt = np.array([ 1.35847161e+05, -4.92212036e-02, -2.79453873e+01])

fig, ax = plt.subplots(1,1,figsize=(10,8))
t_new = np.linspace(0, T, int((T/dt)))
ax.plot(Model.time_series[::50], np.sum(Model.linages_time_series, axis=0)[::50], marker = 'o', ms = 8, color = 'indianred', linestyle = '', label = 'simulation')

to = 12
b = 1.26
tau = np.exp(t_new-to)
N_total_exp = ((tau**(beta*b)-tau**(nu))/(beta*n_linages*b-nu)) + 200 - (1/(beta*b*200))*(tau**(beta*b)*-1)
ax.plot(t_new, N_total_exp, linewidth = 4, linestyle = 'dashed', alpha = 0.4, label = 'exponential model')

ax.set_xlabel(r'time $t$', fontsize = 20)
ax.set_ylabel(r'$N(t)$', fontsize = 20)
ax.tick_params(labelsize = 22)
ax.set_yscale('log')
ax.set_xlim(0, T)
ax.legend(loc = 0, fontsize = 20)
counter = 0
while(os.path.isfile('../Figures/N_total_%d.png'%(counter))):
    counter+=1
#fig.savefig('../Figures/N_total_%d.png'%(0))

# %%
fig1, ax1 = plt.subplots(4,2,figsize=(20,32))
fig2, ax2 = plt.subplots(1,1,figsize=(10,8))
k_array = np.array([0, 5, 10, 50, 200])
Model.plot_entropy_drop(k_array = k_array, ax1 = ax1, ax2 = ax2)

counter = 0
while(os.path.isfile('../Figures/Muller_plots_entropy_%d.png'%(counter))):
    counter+=1
#fig1.savefig('../Figures/Muller_plots_entropy_%d.png'%(0))

counter = 0
while(os.path.isfile('../Figures/Entropy_drop_%d.png'%(counter))):
    counter+=1
#fig2.savefig('../Figures/Entropy_drop_%d.png'%(0))

# %% [markdown]
# ## Ensemble

# %%
# %%time
T = 90
dt = 0.01
run_ensemble_deterministic_model(Sequences = Left_tail, n_linages = 200, n_seq = 500000, nu = 1, beta = 0.02,
                                 gamma = 0, T = T, master_Sequence_energy = 0, initial_time = 60, dt = dt,
                                 n_sim = 200,comment = 'left_tail_death', new = True)
# Out:
# 0 ...
# 40 ...
# 80 ...
# 120 ...
# 160 ...
# Ensemble size: 28549
# CPU times: user 10min 23s, sys: 2.07 s, total: 10min 25s
# Wall time: 33min 7s

# %%
fig, ax = plt.subplots(1,1, figsize = (10, 8))
bins = 60
n_linages = 200
popt, pcov = plot_histogram_energy_subsampling(bins = bins, n_linages = n_linages, 
                                               Sequences = Sequences, sub_energies = sub_energies, fig = fig, ax = ax)
display(Math(r'y = %.3f e^{%.3f(\epsilon%.1f)^2}'%((popt[0]), popt[1], popt[2])))
# Out:
# integral a*$\pi$: 426776.44387101685
# $\displaystyle y = 135847.161 e^{-0.049(\epsilon-27.9)^2}$

# %%
(np.min(energies)+np.log(N_A))/0.2
# Out:
# 73.62449971471835

# %%
T = 90
dt = 0.01
beta = 0.2
gamma = 0
nu = 1
eo = np.min(energies)
b = 1.26
to = (eo+np.log(N_A))/beta
print(to, np.exp(beta*to)/N_A)
initial_time = 60
fig, ax = plt.subplots(1, 1, figsize = (10,8))
plot_activation_rate_ensemble_deterministic(beta= beta, b= b, nu = nu, gamma = gamma, T = T, initial_time = initial_time, eo=eo, dt = dt, popt = popt, energies = energies, comment = 'left_tail', gaussian = False, exponential = True, ax = ax)
rho_new = np.linspace(5e-18, 1e-16, 100)
alpha = n_linages/len(Left_tail)
print(n)
ax.plot(rho_new, (alpha/(b*beta))*(np.exp(-beta*b*to)*(rho_new*N_A)**(b)-1), linewidth = 4, linestyle = 'dashed', alpha = 0.4, label = 'exponential model', color = 'tab:orange')
# Out:
# 73.62449971471835 4.12279641197952e-18
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-40852fde61bd> in <module>
#      10 initial_time = 60
#      11 fig, ax = plt.subplots(1, 1, figsize = (10,8))
# ---> 12 plot_activation_rate_ensemble_deterministic(beta= beta, b= b, nu = nu, gamma = gamma, T = T, initial_time = initial_time, eo=eo, dt = dt, popt = popt, energies = energies, comment = 'left_tail', gaussian = False, exponential = True, ax = ax)
#      13 rho_new = np.linspace(5e-18, 1e-16, 100)
#      14 alpha = n_linages/len(Left_tail)
#
# ~/Documents/Research/Evolution_Immune_System/Codes/Immuno_models.py in plot_activation_rate_ensemble_deterministic(beta, b, nu, gamma, T, initial_time, eo, dt, popt, energies, comment, gaussian, exponential, ax)
#     654         #____________ Read and plot the activation of linages as function of antigen concetration
#     655         t_new = np.linspace(initial_time, T, int((T-initial_time)/dt))
# --> 656         activation_time_series = pickle.load( open( "../Text_files/ensemble_deterministic_model_activation_time_series_"+comment+".pkl", "rb" ) )
#     657         activation_time_series_var = pickle.load( open( "../Text_files/ensemble_deterministic_model_activation_time_series_var_"+comment+".pkl", "rb" ) )
#     658         ax.plot(np.exp(beta*t_new[1:][::50][np.where(activation_time_series[1:][::50]!=0)])/N_A, activation_time_series[1:][::50][np.where(activation_time_series[1:][::50]!=0)], linestyle = '', marker = '.', ms = 20, linewidth = 4, color = 'indigo', label = 'simulation')
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Text_files/ensemble_deterministic_model_activation_time_series_left_tail.pkl'

# %%
fig, ax = plt.subplots(1, 1, figsize = (10,8))
n_bins = 20
plot_size_distribution_ensemble_deterministic(beta= beta, b= b, nu = nu, gamma = gamma, T = T, eo = eo, dt = dt, n_bins = n_bins, density = True, popt = popt,
                                              comment = 'left_tail', gaussian = False, exponential = True, ax = ax)

activated_linages_size = pickle.load( open( "../Text_files/ensemble_deterministic_model_linage_sizesleft_tail.pkl", "rb" ) )
n_array = np.linspace(1,np.max(activated_linages_size), 100)
ax.plot(n_array, ((alpha/(beta*b))*(np.exp(beta*b*(T-to))*n_array**(-b*beta)-1))/((((alpha/(beta*b))*(np.exp(beta*b*(T-to))*n_array**(-b*beta)-1)))[0]), linewidth = 4, linestyle = 'dashed', alpha = 0.4, color = 'steelblue', label = 'exponential model')

# %%
fig, ax = plt.subplots(1, 1, figsize = (10,8))
plot_N_total_ensemble_deterministic(beta= beta, b= b, nu = nu, gamma = gamma, T = T, initial_time = initial_time, eo = eo, dt = 0.01, popt = popt, comment = 'left_tail',
                                    gaussian = False, exponential = True, ax = ax)
ax.set_xlim(initial_time, T)

#fig.savefig('../Figures/N_total_ensemble.png')
# Out:
# (60.0, 90.0)

# %%
fig, ax = plt.subplots(1, 1, figsize = (10,8))
plot_entropy_ensemble_deterministic(beta = beta, b= b, nu = nu, gamma = gamma,  T = T, initial_time = initial_time, eo = eo, dt = 0.01, popt = popt, comment = 'left_tail',
                                    gaussian = False, exponential = True, ax = ax)
#fig.savefig('../Figures/Entropy_ensemble.png')

# %%
(1e5/N_A)*1e3
# Out:
# 1.6605390671738467e-16
