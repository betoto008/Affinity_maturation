# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as sc
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
data=(np.loadtxt('../Codes/Ising_model/output.txt'))
E = data[:,0]

# %%
fig, ax = plt.subplots(figsize = (10,8))
L = 80
h = 20
ds = np.linspace(0, L );
data_E = np.histogram(E, bins = 'auto', density = True);
ax.plot(data_E[1][:-1], data_E[0]/(1e10*(2**(L))**(-1)*np.exp(-data_E[1][:-1]/1)), color = 'olive', linestyle = '', marker = '*', ms = 10);
#ax.plot(data_E[1][:-1], data_E[0], color = 'olive', linestyle = '', marker = '*', ms = 10);

#ax.plot(data_E[1][:-1], (2**(50))**(-1)*np.exp(-data_E[1][:-1]/1)*sc.comb(L, (data_E[1][:-1]+L)/2), color = 'olive', linestyle = '--', marker = '', ms = 10);
ax.plot(ds*2-L, sc.comb(L, ds)/2**(L) , linewidth = 4 , label = 'Ising 1D', color = 'darkblue', linestyle = '--');
ax.set_yscale('log');
ax.set_yscale('log');
ax.set_xlabel('Energy $\epsilon$', fontsize = 22)
ax.set_ylabel(r'Density of states $\rho$', fontsize = 22)
ax.tick_params(labelsize = 23)
ax.legend(loc = 0, fontsize = 22)
fig.savefig('../Figures/Density_of_States_MCMC_Ising1D_temperature.png')

# %%
print('%.2e'%(2**80),'%.2e'%(len(E)))
# Out:
# 1.21e+24 8.00e+06

# %%
fig, ax = plt.subplots(figsize = (10,8))
L = 30.
h = 2.
d = np.arange(L+1);

ax.plot(d, (sc.comb(L, d)*(h-1)**d) , linewidth = 4 , label = 'Ising 1D', color = 'darkblue', linestyle = '--');
ax.plot(d, 2**L*np.exp(-0.5*(L/2-d)**2/(0.25*L))/(np.sqrt(2*np.pi*(0.25*L))) , linewidth = 4 , label = 'Ising 1D', color = 'darkorange', linestyle = '--');

ax.hlines((h-1)**L, 0,L, linestyle = '--', alpha = .3, color = 'silver')

ax.set_yscale('log');
ax.set_xlabel('Energy $\epsilon$', fontsize = 22)
ax.set_ylabel(r'Density of states $\rho$', fontsize = 22)
ax.tick_params(labelsize = 23)
ax.legend(loc = 0, fontsize = 22)

# %%
fig, ax = plt.subplots(figsize = (10,8))
L = 30.
h = 2
d = np.arange(1, L+1);

ax.plot(d, np.log((sc.comb(L, (d)))*(h-1)**(d)) - np.log((sc.comb(L, (d-1)*(h-1)**(d-1)))) , linewidth = 4 , label = 'Ising 1D', color = 'darkblue', linestyle = '--');
ax.plot(d,  4*(L/2-d)/L, linewidth = 4 , label = 'Ising 1D', color = 'darkorange', linestyle = '--');

ax.hlines((h-1)**L/h**(L), 0,L, linestyle = '--', alpha = .3, color = 'silver')

#ax.set_ylim(bottom = 0);
#ax.set_xlim(left = 0, right = 15);
ax.set_xlabel('Energy $\epsilon$', fontsize = 22)
ax.set_ylabel(r'Density of states $\rho$', fontsize = 22)
ax.tick_params(labelsize = 23)
ax.legend(loc = 0, fontsize = 22)

# %%
fig, ax = plt.subplots(figsize = (10,8))
L = 30.
h = 2.
d = np.arange(L+1);

P0 = 2**L*np.exp(-0.5*(L/2-d)**2/(0.25*L))/(np.sqrt(2*np.pi*(0.25*L))) 

ax.plot(d, np.log((sc.comb(L, d)*(h-1)**d) / P0), linewidth = 4 , label = 'Ising 1D', color = 'darkblue', linestyle = '--');
#ax.plot(d,  linewidth = 4 , label = 'Ising 1D', color = 'darkorange', linestyle = '--');

ax.hlines((h-1)**L, 0,L, linestyle = '--', alpha = .3, color = 'silver')

#ax.set_yscale('log');
ax.set_xlabel('Energy $\epsilon$', fontsize = 22)
ax.set_ylabel(r'Density of states $\rho$', fontsize = 22)
ax.tick_params(labelsize = 23)
ax.legend(loc = 0, fontsize = 22)
